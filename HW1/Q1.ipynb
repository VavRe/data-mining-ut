# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('./Datasets/house.csv')

# %%
df_def = df.copy()
df.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  2919.000000  2919.000000  2433.000000    2919.000000  2919.000000
# mean   1460.000000    57.137718    69.305795   10168.114080     6.089072
# std     842.787043    42.517628    23.344905    7886.996359     1.409947
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     730.500000    20.000000    59.000000    7478.000000     5.000000
# 50%    1460.000000    50.000000    68.000000    9453.000000     6.000000
# 75%    2189.500000    70.000000    80.000000   11570.000000     7.000000
# max    2919.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  2919.000000  2919.000000   2919.000000  2896.000000  2918.000000  ...
# mean      5.564577  1971.312778   1984.264474   102.201312   441.423235  ...
# std       1.113131    30.291442     20.894344   179.334253   455.610826  ...
# min       1.000000  1872.000000   1950.000000     0.000000     0.000000  ...
# 25%       5.000000  1953.500000   1965.000000     0.000000     0.000000  ...
# 50%       5.000000  1973.000000   1993.000000     0.000000   368.500000  ...
# 75%       6.000000  2001.000000   2004.000000   164.000000   733.000000  ...
# max       9.000000  2010.000000   2010.000000  1600.000000  5644.000000  ...
#
#         WoodDeckSF  OpenPorchSF  EnclosedPorch    3SsnPorch  ScreenPorch  \
# count  2919.000000  2919.000000    2919.000000  2919.000000  2919.000000
# mean     93.709832    47.486811      23.098321     2.602261    16.062350
# std     126.526589    67.575493      64.244246    25.188169    56.184365
# min       0.000000     0.000000       0.000000     0.000000     0.000000
# 25%       0.000000     0.000000       0.000000     0.000000     0.000000
# 50%       0.000000    26.000000       0.000000     0.000000     0.000000
# 75%     168.000000    70.000000       0.000000     0.000000     0.000000
# max    1424.000000   742.000000    1012.000000   508.000000   576.000000
#
#           PoolArea       MiscVal       MoSold       YrSold      SalePrice
# count  2919.000000   2919.000000  2919.000000  2919.000000    2919.000000
# mean      2.251799     50.825968     6.213087  2007.792737  181344.083590
# std      35.663946    567.402211     2.714762     1.314964   78013.313167
# min       0.000000      0.000000     1.000000  2006.000000   34900.000000
# 25%       0.000000      0.000000     4.000000  2007.000000  130000.000000
# 50%       0.000000      0.000000     6.000000  2008.000000  163900.000000
# 75%       0.000000      0.000000     8.000000  2009.000000  214900.000000
# max     800.000000  17000.000000    12.000000  2010.000000  755000.000000
#
# [8 rows x 38 columns]

# %%
# Showing First 5 records
df.head(5)
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# 0   2008        WD         Normal     208500
# 1   2007        WD         Normal     181500
# 2   2008        WD         Normal     223500
# 3   2006        WD        Abnorml     140000
# 4   2008        WD         Normal     250000
#
# [5 rows x 81 columns]

# %% [markdown]
# # Preprocessing

# %% [markdown]
# ## Deal with Null Values

# %%
def null_check(df):
    missing_values = df.isnull().sum()
    for column,count_null in missing_values.items():
        if count_null > 0:
            print(f" {column} : { count_null }")

# %%
null_check(df)
# Out:
#  MSZoning : 4
#  LotFrontage : 486
#  Alley : 2721
#  Utilities : 2
#  Exterior1st : 1
#  Exterior2nd : 1
#  MasVnrType : 24
#  MasVnrArea : 23
#  BsmtQual : 81
#  BsmtCond : 82
#  BsmtExposure : 82
#  BsmtFinType1 : 79
#  BsmtFinSF1 : 1
#  BsmtFinType2 : 80
#  BsmtFinSF2 : 1
#  BsmtUnfSF : 1
#  TotalBsmtSF : 1
#  Electrical : 1
#  BsmtFullBath : 2
#  BsmtHalfBath : 2
#  KitchenQual : 1
#  Functional : 2
#  FireplaceQu : 1420
#  GarageType : 157
#  GarageYrBlt : 159
#  GarageFinish : 159
#  GarageCars : 1
#  GarageArea : 1
#  GarageQual : 159
#  GarageCond : 159
#  PoolQC : 2909
#  Fence : 2348
#  MiscFeature : 2814
#  SaleType : 1

# %%
# Deleting Rows with less than 5% null values on columns
delete_threshold = 0.05 * df.shape[0]
pre_len = len(df)
for column,count_null in missing_values.items():
    if count_null != 0 and count_null < delete_threshold:
        print(f"True for {column}")
        df.dropna(subset=column, inplace=True)
after_len = len(df)
print(f" { pre_len - after_len } rows removed!")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 4
#       2 delete_threshold = 0.05 * df.shape[0]
#       3 pre_len = len(df)
# ----> 4 for column,count_null in missing_values.items():
#       5     if count_null != 0 and count_null < delete_threshold:
#       6         print(f"True for {column}")
#
# NameError: name 'missing_values' is not defined

# %%
null_check(df)
# Out:
#  LotFrontage : 465
#  Alley : 2606
#  FireplaceQu : 1342
#  GarageType : 141
#  GarageYrBlt : 142
#  GarageFinish : 142
#  GarageQual : 142
#  GarageCond : 142
#  PoolQC : 2789
#  Fence : 2241
#  MiscFeature : 2700

# %%
print(df["LotFrontage"].describe())
df["LotFrontage"].hist()
# Out:
# count    2334.000000
# mean       69.100686
# std        23.352398
# min        21.000000
# 25%        58.000000
# 50%        68.000000
# 75%        80.000000
# max       313.000000
# Name: LotFrontage, dtype: float64
# <Axes: >

# %%
df["LotFrontage"] = df["LotFrontage"].fillna(df["LotFrontage"].median())
null_check(df)
# Out:
#  Alley : 2606
#  FireplaceQu : 1342
#  GarageType : 141
#  GarageYrBlt : 142
#  GarageFinish : 142
#  GarageQual : 142
#  GarageCond : 142
#  PoolQC : 2789
#  Fence : 2241
#  MiscFeature : 2700

# %%
df["Alley"].value_counts()
# Out:
# Grvl    118
# Pave     75
# Name: Alley, dtype: int64

# %%
df["Alley"] = df["Alley"].fillna("No Access")
null_check(df)
# Out:
#  FireplaceQu : 1342
#  GarageType : 141
#  GarageYrBlt : 142
#  GarageFinish : 142
#  GarageQual : 142
#  GarageCond : 142
#  PoolQC : 2789
#  Fence : 2241
#  MiscFeature : 2700

# %%
print(df["FireplaceQu"].value_counts(),f"\n {4*'======'}")
df["FireplaceQu"] = df["FireplaceQu"].fillna("No FirePlace")
null_check(df)
# Out:
# Gd    721
# TA    578
# Fa     73
# Po     44
# Ex     41
# Name: FireplaceQu, dtype: int64
#  ========================
#  GarageType : 141
#  GarageYrBlt : 142
#  GarageFinish : 142
#  GarageQual : 142
#  GarageCond : 142
#  PoolQC : 2789
#  Fence : 2241
#  MiscFeature : 2700

# %%
garage_attrs = ["GarageType","GarageYrBlt","GarageFinish","GarageQual","GarageCond"]
for attr in garage_attrs:
    df[attr] = df[attr].fillna("No Garage")
null_check(df)
# Out:
#  PoolQC : 2789
#  Fence : 2241
#  MiscFeature : 2700

# %%
df["PoolQC"] = df["PoolQC"].fillna("No Pool")
df["Fence"] = df["Fence"].fillna("No Fence")
df["MiscFeature"] = df["MiscFeature"].fillna("None")
null_check(df)

# %% [markdown]
# ## Dealing with Outliers

# %%
first_quantile = df["SalePrice"].quantile(0.25) 
third_quantile = df["SalePrice"].quantile(0.75) 
IQR = third_quantile - first_quantile 
outlier_seal = first_quantile - 1.5*IQR
outlier_floor = third_quantile + 1.5*IQR

outliers = df[(df["SalePrice"] < outlier_seal ) | (df["SalePrice"] > outlier_floor)]
outliers.describe()
# Out:
#                 Id  MSSubClass  LotFrontage        LotArea  OverallQual  \
# count   115.000000  115.000000   115.000000     115.000000   115.000000
# mean   1376.417391   44.565217    79.556522   14477.104348     7.513043
# std     863.511994   30.619089    24.023085   20493.965517     1.778849
# min      12.000000   20.000000    21.000000    1484.000000     4.000000
# 25%     626.000000   20.000000    64.000000    8801.500000     6.000000
# 50%    1374.000000   30.000000    77.000000   11844.000000     8.000000
# 75%    2133.000000   60.000000    92.500000   14191.500000     9.000000
# max    2912.000000  160.000000   174.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count   115.000000   115.000000    115.000000   115.000000   115.000000  ...
# mean      5.356522  1986.826087   1995.034783   282.817391   742.156522  ...
# std       1.085723    27.503831     17.376598   307.830598   646.433462  ...
# min       2.000000  1890.000000   1950.000000     0.000000     0.000000  ...
# 25%       5.000000  1970.500000   1993.000000     0.000000     0.000000  ...
# 50%       5.000000  2003.000000   2003.000000   208.000000   816.000000  ...
# 75%       5.000000  2006.000000   2007.000000   443.000000  1325.000000  ...
# max       9.000000  2010.000000   2010.000000  1378.000000  2188.000000  ...
#
#        WoodDeckSF  OpenPorchSF  EnclosedPorch   3SsnPorch  ScreenPorch  \
# count  115.000000   115.000000     115.000000  115.000000   115.000000
# mean   146.617391    68.460870      18.356522    5.278261    17.008696
# std    145.522385    74.228226      55.166286   34.427791    60.093129
# min      0.000000     0.000000       0.000000    0.000000     0.000000
# 25%      0.000000     0.000000       0.000000    0.000000     0.000000
# 50%    140.000000    56.000000       0.000000    0.000000     0.000000
# 75%    205.000000    98.000000       0.000000    0.000000     0.000000
# max    857.000000   444.000000     291.000000  304.000000   410.000000
#
#          PoolArea      MiscVal      MoSold       YrSold      SalePrice
# count  115.000000   115.000000  115.000000   115.000000     115.000000
# mean     4.826087    31.304348    6.252174  2007.808696  420327.408696
# std     51.754017   284.809945    2.749301     1.356567   81721.840338
# min      0.000000     0.000000    1.000000  2006.000000  341000.000000
# 25%      0.000000     0.000000    5.000000  2007.000000  372402.000000
# 50%      0.000000     0.000000    6.000000  2008.000000  394432.000000
# 75%      0.000000     0.000000    8.000000  2009.000000  439390.000000
# max    555.000000  3000.000000   12.000000  2010.000000  755000.000000
#
# [8 rows x 37 columns]

# %%
df.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  2799.000000  2799.000000  2799.000000    2799.000000  2799.000000
# mean   1451.777778    57.381208    68.917828   10105.793855     6.135763
# std     842.540441    42.786286    21.327756    7876.164835     1.378173
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     721.500000    20.000000    60.000000    7478.000000     5.000000
# 50%    1448.000000    50.000000    68.000000    9457.000000     6.000000
# 75%    2175.500000    70.000000    79.000000   11539.500000     7.000000
# max    2919.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond   YearBuilt  YearRemodAdd  MasVnrArea   BsmtFinSF1  ...  \
# count  2799.000000  2799.00000   2799.000000  2799.00000  2799.000000  ...
# mean      5.584852  1971.61522   1984.590211   104.56806   454.047160  ...
# std       1.099678    30.34338     20.710684   181.17756   455.377134  ...
# min       1.000000  1872.00000   1950.000000     0.00000     0.000000  ...
# 25%       5.000000  1954.00000   1966.000000     0.00000     0.000000  ...
# 50%       5.000000  1974.00000   1993.000000     0.00000   384.000000  ...
# 75%       6.000000  2001.00000   2004.000000   169.00000   740.000000  ...
# max       9.000000  2010.00000   2010.000000  1600.00000  5644.000000  ...
#
#         WoodDeckSF  OpenPorchSF  EnclosedPorch    3SsnPorch  ScreenPorch  \
# count  2799.000000  2799.000000    2799.000000  2799.000000  2799.000000
# mean     96.111111    48.008574      22.950697     2.649518    16.323330
# std     127.592488    67.495140      64.379707    25.497377    56.508902
# min       0.000000     0.000000       0.000000     0.000000     0.000000
# 25%       0.000000     0.000000       0.000000     0.000000     0.000000
# 50%       0.000000    28.000000       0.000000     0.000000     0.000000
# 75%     168.000000    70.000000       0.000000     0.000000     0.000000
# max    1424.000000   742.000000    1012.000000   508.000000   576.000000
#
#           PoolArea       MiscVal       MoSold       YrSold      SalePrice
# count  2799.000000   2799.000000  2799.000000  2799.000000    2799.000000
# mean      2.147910     50.486245     6.209718  2007.792426  181582.264380
# std      34.851983    574.888535     2.717316     1.319074   77390.278163
# min       0.000000      0.000000     1.000000  2006.000000   34900.000000
# 25%       0.000000      0.000000     4.000000  2007.000000  131000.000000
# 50%       0.000000      0.000000     6.000000  2008.000000  164000.000000
# 75%       0.000000      0.000000     8.000000  2009.000000  214900.000000
# max     800.000000  17000.000000    12.000000  2010.000000  755000.000000
#
# [8 rows x 37 columns]

# %% [markdown]
# ## Find Paradoxes

# %%
df_def = df_def.sort_values("SalePrice", ascending=False)
mask = (df_def["SalePrice"] > df_def["SalePrice"].shift()) & (df_def["LotArea"] < df_def["LotArea"].shift())
mask.value_counts()
# Out:
# False    2919
# dtype: int64

# %%
mask.head(10)
# Out:
# 691     False
# 2851    False
# 1182     True
# 1169     True
# 1827    False
# 898      True
# 803      True
# 2334    False
# 1046     True
# 440     False
# Name: LotArea, dtype: bool

# %%
df = df.sort_values("SalePrice", ascending=False)
mask = (df['LotArea'] > df['LotArea'].shift()) 
mask.value_counts()
# Out:
# False    1425
# True     1374
# Name: LotArea, dtype: int64

# %%
df.head(10)
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street      Alley  \
# 691    692          60       RL        104.0    21535   Pave  No Access
# 2851  2852          60       RL         90.0    11250   Pave  No Access
# 1182  1183          60       RL        160.0    15623   Pave  No Access
# 1169  1170          60       RL        118.0    35760   Pave  No Access
# 1827  1828          50       RM         51.0     6120   Pave  No Access
# 898    899          20       RL        100.0    12919   Pave  No Access
# 803    804          60       RL        107.0    13891   Pave  No Access
# 2334  2335          60       RL         88.0    11762   Pave  No Access
# 1046  1047          60       RL         85.0    16056   Pave  No Access
# 440    441          20       RL        105.0    15431   Pave  No Access
#
#      LotShape LandContour Utilities  ... PoolArea   PoolQC     Fence  \
# 691       IR1         Lvl    AllPub  ...        0  No Pool  No Fence
# 2851      IR1         Lvl    AllPub  ...        0  No Pool  No Fence
# 1182      IR1         Lvl    AllPub  ...      555       Ex     MnPrv
# 1169      IR1         Lvl    AllPub  ...        0  No Pool  No Fence
# 1827      Reg         Lvl    AllPub  ...        0  No Pool  No Fence
# 898       IR1         Lvl    AllPub  ...        0  No Pool  No Fence
# 803       Reg         Lvl    AllPub  ...        0  No Pool  No Fence
# 2334      Reg         Lvl    AllPub  ...        0  No Pool  No Fence
# 1046      IR1         Lvl    AllPub  ...        0  No Pool  No Fence
# 440       Reg         Lvl    AllPub  ...        0  No Pool  No Fence
#
#      MiscFeature MiscVal MoSold YrSold  SaleType  SaleCondition  SalePrice
# 691         None       0      1   2007        WD         Normal     755000
# 2851        None       0      5   2006        WD         Normal     745000
# 1182        None       0      7   2007        WD        Abnorml     745000
# 1169        None       0      7   2006        WD         Normal     625000
# 1827        None       0      2   2009        WD         Normal     611657
# 898         None       0      3   2010       New        Partial     611657
# 803         None       0      1   2009       New        Partial     582933
# 2334        None       0      9   2007        WD         Normal     556581
# 1046        None       0      7   2006       New        Partial     556581
# 440         None       0      4   2009        WD         Normal     555000
#
# [10 rows x 81 columns]

# %%
## Reasons -> More LotFrontage , Has Pool, Fence, ( 3 to 2 )
# Out:
#           Id  MSSubClass MSZoning  LotFrontage  LotArea Street      Alley  \
# 691      NaN         NaN     None          NaN      NaN   None       None
# 2851   692.0        60.0       RL        104.0  21535.0   Pave  No Access
# 1182  2852.0        60.0       RL         90.0  11250.0   Pave  No Access
# 1169  1183.0        60.0       RL        160.0  15623.0   Pave  No Access
# 1827  1170.0        60.0       RL        118.0  35760.0   Pave  No Access
# ...      ...         ...      ...          ...      ...    ...        ...
# 2313   969.0        50.0       RM         50.0   5925.0   Pave  No Access
# 916   2314.0        60.0       RL         58.0  13204.0   Pave  No Access
# 2271   917.0        20.0  C (all)         50.0   9000.0   Pave  No Access
# 495   2272.0        60.0       RL         61.0  11339.0   Pave  No Access
# 1756   496.0        30.0  C (all)         60.0   7879.0   Pave  No Access
#
#      LotShape LandContour Utilities  ... PoolArea   PoolQC     Fence  \
# 691      None        None      None  ...      NaN     None      None
# 2851      IR1         Lvl    AllPub  ...      0.0  No Pool  No Fence
# 1182      IR1         Lvl    AllPub  ...      0.0  No Pool  No Fence
# 1169      IR1         Lvl    AllPub  ...    555.0       Ex     MnPrv
# 1827      IR1         Lvl    AllPub  ...      0.0  No Pool  No Fence
# ...       ...         ...       ...  ...      ...      ...       ...
# 2313      Reg         Lvl    AllPub  ...      0.0  No Pool      GdWo
# 916       IR1         Lvl    AllPub  ...      0.0  No Pool  No Fence
# 2271      Reg         Lvl    AllPub  ...      0.0  No Pool  No Fence
# 495       IR1         Lvl    AllPub  ...      0.0  No Pool  No Fence
# 1756      Reg         Lvl    AllPub  ...      0.0  No Pool      GdWo
#
#      MiscFeature MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# 691         None     NaN    NaN     NaN      None           None        NaN
# 2851        None     0.0    1.0  2007.0        WD         Normal   755000.0
# 1182        None     0.0    5.0  2006.0        WD         Normal   745000.0
# 1169        None     0.0    7.0  2007.0        WD        Abnorml   745000.0
# 1827        None     0.0    7.0  2006.0        WD         Normal   625000.0
# ...          ...     ...    ...     ...       ...            ...        ...
# 2313        None     0.0    5.0  2009.0        WD        Abnorml    37900.0
# 916         None     0.0    5.0  2007.0       New        Partial    35311.0
# 2271        None     0.0   10.0  2006.0        WD        Abnorml    35311.0
# 495         None     0.0    3.0  2007.0        WD         Normal    34900.0
# 1756        None     0.0   11.0  2009.0        WD        Abnorml    34900.0
#
# [2799 rows x 81 columns]

# %% [markdown]
# # Visualization and Exploration

# %% [markdown]
# ## 1.Mean Price Visualazing in each neighberhoud

# %%
prices = df.groupby("Neighborhood")["SalePrice"].mean().to_dict()
prices = dict(sorted(prices.items(), key = lambda item : item[1] )) 
fig, ax = plt.subplots(figsize=(10,8))
fig.tight_layout()
# fig.subplots_adjust(right=0.5)
bars = ax.barh(list(prices.keys()), list(prices.values()) , height=0.6 , align="edge" )
ax.bar_label(bars)
# for c in ax.containers:
#     ax.bar_label(c, fmt='{:,.0f}')  # ≥ 3.7

ax.plot
# Out:
# <bound method Axes.plot of <Axes: >>

# %% [markdown]
# ## Top 5s

# %%
## 5 Neighborhoods with the most houses
df.groupby("Neighborhood").size().nlargest(5)
# Out:
# Neighborhood
# NAmes      443
# CollgCr    267
# OldTown    239
# Edwards    194
# Somerst    182
# dtype: int64

# %%
## 5 Neighberhood with priciest houses
df.groupby("Neighborhood")["SalePrice"].max().nlargest(5)
# Out:
# Neighborhood
# NoRidge    755000
# CollgCr    745000
# BrkSide    611657
# NridgHt    611657
# Somerst    611657
# Name: SalePrice, dtype: int64

# %% [markdown]
# ## #Bedrooms Effect on Price

# %%
## The Effect of Number of Bedrooms on Price 
df.boxplot(column="SalePrice", by="BedroomAbvGr")
# Out:
# <Axes: title={'center': 'SalePrice'}, xlabel='BedroomAbvGr'>

# %% [markdown]
# ## Correlation Analysis

# %%
corr_matrix = df.corr()
sns.heatmap(corr_matrix)
plt.show()
# Out:
# /tmp/ipykernel_3302/570970446.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr_matrix = df.corr()

# %%
corr_matrix.unstack().sort_values(ascending=False).drop_duplicates()
# Out:
# Id             Id              1.000000
# GarageCars     GarageArea      0.889700
# YearBuilt      GarageYrBlt     0.834812
# GrLivArea      TotRmsAbvGrd    0.808354
# 1stFlrSF       TotalBsmtSF     0.801670
#                                  ...
# OverallCond    YearBuilt      -0.368477
# EnclosedPorch  YearBuilt      -0.374073
# BsmtUnfSF      BsmtFullBath   -0.398678
# MSSubClass     LotFrontage    -0.417359
# BsmtUnfSF      BsmtFinSF1     -0.477404
# Length: 704, dtype: float64

# %% [markdown]
# ## House Prices Distribution

# %%
data = df["SalePrice"].to_numpy()
fig , axes = plt.subplots(nrows=3,ncols=1,figsize=(10,10))
fig.subplots_adjust(hspace=0.5)
axes[0].hist(data)
axes[0].set_title("Histogram of SalePrice Distribution")
axes[0].set_ylabel("Frequency")
sns.kdeplot(data, ax=axes[1])
axes[1].set_title("Density Function of SalePrice ")
axes[1].set_xlim(0)
axes[2].boxplot(data, whis=1.5)
axes[2].set_ylabel("Box Plot")
plt.show()
